# %% [markdown]
# # Data Science Capstone, Part 2:
# ### Obtaining GeoLocations for Toronto's Postal Codes

# %% [markdown]
# In this second notebook for the assignment of week 3 in the Data Science Capstone project by IBM on Coursera, we will obtain geolocation data for the postcodes previously obtained in the notebook pertaining to part 1. Geolocation data will be obtained in the form of latitude and longitude for each postcode via the python library geocoder.

# %%
# Import required libraries

import pandas as pd
import numpy as np
try:
    import geocoder # if module geocoder is not found, first install it via pip
except ModuleNotFoundError:
    # %pip install geocoder
    import geocoder

# %% [markdown]
# When using this notebook, the postal code dataframe for Toronto should have already been created by running the previous notebook. We then load the dataframe from the csv file saved at the end of that notebook.

# %%
toronto_postcodes = pd.read_csv("TorontoPost.csv", index_col = 0) # using the default read_csv method from pandas to load the datafrae

# %%
toronto_postcodes.head() # Checking that the dataframe was loaded correctly
# Out:
#   Postal Code           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# At this point we can use the geocoder library to obtain the coordinates for each postcode. Such coordinates will be stored in lists that will later be added to the existent dataframe in order to create a dataframe including also the geolocation of each postcode.

# %%
# Create lists to store the geo-coordinates for each postcode

latitudes = []
longitudes = []

# Loop through the dataframe
for postal_code in toronto_postcodes['Postal Code']:
    # initialize your variable to None
    print("Obtaining Geo-coordinates for {}...".format(postal_code))
    lat_lng_coords = None

    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng

    latitudes.append(lat_lng_coords[0])
    longitudes.append(lat_lng_coords[1])
    print("Geo-coordinates obtained for {}".format(postal_code))
    
# Add the latitude and longitude columns to the existent dataframe

toronto_postcodes['Latitude'] = latitudes
toronto_postcodes['Longitude'] = longitudes

toronto_postcodes.head() # check that everything is in place
# Out:
# Obtaining Geo-coordinates for M3A...
# Geo-coordinates obtained for M3A
# Obtaining Geo-coordinates for M4A...
# Geo-coordinates obtained for M4A
# Obtaining Geo-coordinates for M5A...
# Geo-coordinates obtained for M5A
# Obtaining Geo-coordinates for M6A...
# Geo-coordinates obtained for M6A
# Obtaining Geo-coordinates for M7A...
# Geo-coordinates obtained for M7A
# Obtaining Geo-coordinates for M9A...
# Geo-coordinates obtained for M9A
# Obtaining Geo-coordinates for M1B...
# Geo-coordinates obtained for M1B
# Obtaining Geo-coordinates for M3B...
# Geo-coordinates obtained for M3B
# Obtaining Geo-coordinates for M4B...
# Geo-coordinates obtained for M4B
# Obtaining Geo-coordinates for M5B...
# Geo-coordinates obtained for M5B
# Obtaining Geo-coordinates for M6B...
# Geo-coordinates obtained for M6B
# Obtaining Geo-coordinates for M9B...
# Geo-coordinates obtained for M9B
# Obtaining Geo-coordinates for M1C...
# Geo-coordinates obtained for M1C
# Obtaining Geo-coordinates for M3C...
# Geo-coordinates obtained for M3C
# Obtaining Geo-coordinates for M4C...
# Geo-coordinates obtained for M4C
# Obtaining Geo-coordinates for M5C...
# Geo-coordinates obtained for M5C
# Obtaining Geo-coordinates for M6C...
# Geo-coordinates obtained for M6C
# Obtaining Geo-coordinates for M9C...
# Geo-coordinates obtained for M9C
# Obtaining Geo-coordinates for M1E...
# Geo-coordinates obtained for M1E
# Obtaining Geo-coordinates for M4E...
# Geo-coordinates obtained for M4E
# Obtaining Geo-coordinates for M5E...
# Geo-coordinates obtained for M5E
# Obtaining Geo-coordinates for M6E...
# Geo-coordinates obtained for M6E
# Obtaining Geo-coordinates for M1G...
# Geo-coordinates obtained for M1G
# Obtaining Geo-coordinates for M4G...
# Geo-coordinates obtained for M4G
# Obtaining Geo-coordinates for M5G...
# Geo-coordinates obtained for M5G
# Obtaining Geo-coordinates for M6G...
# Geo-coordinates obtained for M6G
# Obtaining Geo-coordinates for M1H...
# Geo-coordinates obtained for M1H
# Obtaining Geo-coordinates for M2H...
# Geo-coordinates obtained for M2H
# Obtaining Geo-coordinates for M3H...
# Geo-coordinates obtained for M3H
# Obtaining Geo-coordinates for M4H...
# Geo-coordinates obtained for M4H
# Obtaining Geo-coordinates for M5H...
# Geo-coordinates obtained for M5H
# Obtaining Geo-coordinates for M6H...
# Geo-coordinates obtained for M6H
# Obtaining Geo-coordinates for M1J...
# Geo-coordinates obtained for M1J
# Obtaining Geo-coordinates for M2J...
# Geo-coordinates obtained for M2J
# Obtaining Geo-coordinates for M3J...
# Geo-coordinates obtained for M3J
# Obtaining Geo-coordinates for M4J...
# Geo-coordinates obtained for M4J
# Obtaining Geo-coordinates for M5J...
# Geo-coordinates obtained for M5J
# Obtaining Geo-coordinates for M6J...
# Geo-coordinates obtained for M6J
# Obtaining Geo-coordinates for M1K...
# Geo-coordinates obtained for M1K
# Obtaining Geo-coordinates for M2K...
# Geo-coordinates obtained for M2K
# Obtaining Geo-coordinates for M3K...
# Geo-coordinates obtained for M3K
# Obtaining Geo-coordinates for M4K...
# Geo-coordinates obtained for M4K
# Obtaining Geo-coordinates for M5K...
# Geo-coordinates obtained for M5K
# Obtaining Geo-coordinates for M6K...
# Geo-coordinates obtained for M6K
# Obtaining Geo-coordinates for M1L...
# Geo-coordinates obtained for M1L
# Obtaining Geo-coordinates for M2L...
# Geo-coordinates obtained for M2L
# Obtaining Geo-coordinates for M3L...
# Geo-coordinates obtained for M3L
# Obtaining Geo-coordinates for M4L...
# Geo-coordinates obtained for M4L
# Obtaining Geo-coordinates for M5L...
# Geo-coordinates obtained for M5L
# Obtaining Geo-coordinates for M6L...
# Geo-coordinates obtained for M6L
# Obtaining Geo-coordinates for M9L...
# Geo-coordinates obtained for M9L
# Obtaining Geo-coordinates for M1M...
# Geo-coordinates obtained for M1M
# Obtaining Geo-coordinates for M2M...
# Geo-coordinates obtained for M2M
# Obtaining Geo-coordinates for M3M...
# Geo-coordinates obtained for M3M
# Obtaining Geo-coordinates for M4M...
# Geo-coordinates obtained for M4M
# Obtaining Geo-coordinates for M5M...
# Geo-coordinates obtained for M5M
# Obtaining Geo-coordinates for M6M...
# Geo-coordinates obtained for M6M
# Obtaining Geo-coordinates for M9M...
# Geo-coordinates obtained for M9M
# Obtaining Geo-coordinates for M1N...
# Geo-coordinates obtained for M1N
# Obtaining Geo-coordinates for M2N...
# Geo-coordinates obtained for M2N
# Obtaining Geo-coordinates for M3N...
# Geo-coordinates obtained for M3N
# Obtaining Geo-coordinates for M4N...
# Geo-coordinates obtained for M4N
# Obtaining Geo-coordinates for M5N...
# Geo-coordinates obtained for M5N
# Obtaining Geo-coordinates for M6N...
# Geo-coordinates obtained for M6N
# Obtaining Geo-coordinates for M9N...
# Geo-coordinates obtained for M9N
# Obtaining Geo-coordinates for M1P...
# Geo-coordinates obtained for M1P
# Obtaining Geo-coordinates for M2P...
# Geo-coordinates obtained for M2P
# Obtaining Geo-coordinates for M4P...
# Geo-coordinates obtained for M4P
# Obtaining Geo-coordinates for M5P...
# Geo-coordinates obtained for M5P
# Obtaining Geo-coordinates for M6P...
# Geo-coordinates obtained for M6P
# Obtaining Geo-coordinates for M9P...
# Geo-coordinates obtained for M9P
# Obtaining Geo-coordinates for M1R...
# Geo-coordinates obtained for M1R
# Obtaining Geo-coordinates for M2R...
# Geo-coordinates obtained for M2R
# Obtaining Geo-coordinates for M4R...
# Geo-coordinates obtained for M4R
# Obtaining Geo-coordinates for M5R...
# Geo-coordinates obtained for M5R
# Obtaining Geo-coordinates for M6R...
# Geo-coordinates obtained for M6R
# Obtaining Geo-coordinates for M7R...
# Geo-coordinates obtained for M7R
# Obtaining Geo-coordinates for M9R...
# Geo-coordinates obtained for M9R
# Obtaining Geo-coordinates for M1S...
# Geo-coordinates obtained for M1S
# Obtaining Geo-coordinates for M4S...
# Geo-coordinates obtained for M4S
# Obtaining Geo-coordinates for M5S...
# Geo-coordinates obtained for M5S
# Obtaining Geo-coordinates for M6S...
# Geo-coordinates obtained for M6S
# Obtaining Geo-coordinates for M1T...
# Geo-coordinates obtained for M1T
# Obtaining Geo-coordinates for M4T...
# Geo-coordinates obtained for M4T
# Obtaining Geo-coordinates for M5T...
# Geo-coordinates obtained for M5T
# Obtaining Geo-coordinates for M1V...
# Geo-coordinates obtained for M1V
# Obtaining Geo-coordinates for M4V...
# Geo-coordinates obtained for M4V
# Obtaining Geo-coordinates for M5V...
# Geo-coordinates obtained for M5V
# Obtaining Geo-coordinates for M8V...
# Geo-coordinates obtained for M8V
# Obtaining Geo-coordinates for M9V...
# Geo-coordinates obtained for M9V
# Obtaining Geo-coordinates for M1W...
# Geo-coordinates obtained for M1W
# Obtaining Geo-coordinates for M4W...
# Geo-coordinates obtained for M4W
# Obtaining Geo-coordinates for M5W...
# Geo-coordinates obtained for M5W
# Obtaining Geo-coordinates for M8W...
# Geo-coordinates obtained for M8W
# Obtaining Geo-coordinates for M9W...
# Geo-coordinates obtained for M9W
# Obtaining Geo-coordinates for M1X...
# Geo-coordinates obtained for M1X
# Obtaining Geo-coordinates for M4X...
# Geo-coordinates obtained for M4X
# Obtaining Geo-coordinates for M5X...
# Geo-coordinates obtained for M5X
# Obtaining Geo-coordinates for M8X...
# Geo-coordinates obtained for M8X
# Obtaining Geo-coordinates for M4Y...
# Geo-coordinates obtained for M4Y
# Obtaining Geo-coordinates for M7Y...
# Geo-coordinates obtained for M7Y
# Obtaining Geo-coordinates for M8Y...
# Geo-coordinates obtained for M8Y
# Obtaining Geo-coordinates for M8Z...
# Geo-coordinates obtained for M8Z
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#    Latitude  Longitude
# 0  43.75245  -79.32991
# 1  43.73057  -79.31306
# 2  43.65512  -79.36264
# 3  43.72327  -79.45042
# 4  43.66253  -79.39188

# %%
# Finally, we can save also this dataframe in a csv format for it to be used in the next notebook
toronto_postcodes.to_csv("TorontoPostGeo.csv")
